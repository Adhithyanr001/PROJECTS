# %%
age_list = [24, 25, 26, 27, 28] 
age_list
# Out:
# [24, 25, 26, 27, 28]

# %%
name_list = ["raju","ram","raj","lal","gopal"]
name_list
# Out:
# ['raju', 'ram', 'raj', 'lal', 'gopal']

# %%
name_list.append("Yazhini")
print(name_list)
# Out:
# ['raju', 'ram', 'raj', 'lal', 'gopal', 'Yazhini', 'Yazhini', 'Yazhini']

# %%
name_list.pop(7)
# Out:
# 'Yazhini'

# %%
name_list.pop(6)
# Out:
# 'Yazhini'

# %%
print(name_list)
# Out:
# ['raju', 'ram', 'raj', 'lal', 'gopal', 'Yazhini']

# %%
age_list.insert(2,30)
print(age_list)
# Out:
# [24, 25, 30, 26, 27, 28]

# %%
name_list.remove("Yazhini")
print(name_list)
# Out:
# ['raju', 'ram', 'raj', 'lal', 'gopal']

# %%
age_list.pop(5)
print(age_list)
# Out:
# [24, 25, 30, 26, 27]

# %%
age_list2 = [29, 30, 26]
age_list.extend(age_list2)
print(age_list)
print(age_list2)
# Out:
# [24, 25, 30, 26, 27, 29, 30, 26]
# [29, 30, 26]

# %%
age_list.sort(reverse = True)
print(age_list)
# Out:
# [30, 30, 29, 27, 26, 26, 25, 24]

# %%
max_age = max(age_list)
min_age = min(age_list)
sum_age = sum(age_list)
print(max_age)
print(min_age)
print(sum_age)
# Out:
# 30
# 24
# 217

# %%
name_list[0]
# Out:
# 'raju'

# %%
name_list[4]
# Out:
# 'gopal'

# %%
name_list[1:]
# Out:
# ['ram', 'raj', 'lal', 'gopal']

# %%
name_list.reverse()
print(name_list)
# Out:
# ['gopal', 'lal', 'raj', 'ram', 'raju']

# %%
student_marks={"gopal":60,
              "lal":70,
              "raj":80,
              "ram":90,
              "raju":50}
              
print(student_marks)
# Out:
# {'gopal': 60, 'lal': 70, 'raj': 80, 'ram': 90, 'raju': 50}

# %%
print(student_marks["gopal"])
# Out:
# 60

# %%
student_marks["Janani"] = 80
print(student_marks)
# Out:
# {'gopal': 60, 'lal': 70, 'raj': 80, 'ram': 90, 'raju': 50, 'Janani': 80}

# %%
student_marks.update({"gopal":82})

# %%
print(student_marks)
# Out:
# {'gopal': 82, 'lal': 70, 'raj': 80, 'ram': 90, 'raju': 50, 'Janani': 80}

# %%
x = student_marks.keys()
print(x)
# Out:
# dict_keys(['gopal', 'lal', 'raj', 'ram', 'raju', 'Janani'])

# %%
x = student_marks.values()
print(x)
# Out:
# dict_values([82, 70, 80, 90, 50, 80])

# %%
x = student_marks.items()
print(x)
# Out:
# dict_items([('gopal', 82), ('lal', 70), ('raj', 80), ('ram', 90), ('raju', 50), ('Janani', 80)])

# %%
my_set = {'a','e','i','o','u','a','a','i'}

# %%
print(my_set)
# Out:
# {'e', 'a', 'u', 'o', 'i'}

# %%
# explanation duplicate values are not allowed in set

# %%
my_set[4] = 's' # set is unordered and unchangable and unindexed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 my_set[4] = 's'
#
# TypeError: 'set' object does not support item assignment

# %%
set1 = {1, 3, 5, 7, 9} 
set2 = {2, 3, 5, 8, 10} 
set3 = set1.union(set2)
print(set3)
# Out:
# {1, 2, 3, 5, 7, 8, 9, 10}

# %%
set1 = {1, 3, 5, 7, 9} 
set2 = {2, 3, 5, 8, 10}
myset = set1.intersection(set2)
print(myset)
# Out:
# {3, 5}

# %%
score = int(input("enter your score:"))
if score>7:
    print("Good effort")
elif score>=4 and score <= 7:
    print("Keep practicing")
else:
    print("There is room for improvement")
# Out:
# enter your score: 3
# There is room for improvement
